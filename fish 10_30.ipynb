# %% [markdown]
# # Using Resampling Methods

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from imblearn.over_sampling import RandomOverSampler

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Load the data
#url = "https://raw.githubusercontent.com/ddw26/Team-Vand/circle_role_crkaide/output_data/df_keys.csv"
url = 'https://raw.githubusercontent.com/ddw26/Team-Vand/circle_role_crkaide/output_data/df_values.csv'
catch_df = pd.read_csv(url)

# Drop the null columns where all values are null
catch_df.columns
# Out:
# Index(['Date file created', 'Month of intercept', 'Time of intercept',
#        'Data sampling period', 'Sub region of trip', 'Kind of day',
#        'Fish target species', 'Type of gear', 'Mode of fishing',
#        'Mode of fishing collapsed', 'Collapsed area of fishing',
#        'Distance from shore', 'Hours on boat', 'Hours fished', 'Catch fish',
#        'Number of fish avail for inspection'],
#       dtype='object')

# %%
catch_df.head()
# Out:
#    Month of intercept  Time of intercept Data sampling period  \
# 0                   2               1512     January/February
# 1                   1               1250     January/February
# 2                   1               1250     January/February
# 3                   2               1303     January/February
# 4                   2               1303     January/February
#
#                  Sub region of trip Kind of day Type of gear Mode of fishing  \
# 0  South Atlantic (NC; SC; GA; EFL)     Weekday  hook & line    Charter boat
# 1  South Atlantic (NC; SC; GA; EFL)     Weekend  hook & line    Charter boat
# 2  South Atlantic (NC; SC; GA; EFL)     Weekend  hook & line    Charter boat
# 3  South Atlantic (NC; SC; GA; EFL)     Weekend  hook & line    Charter boat
# 4  South Atlantic (NC; SC; GA; EFL)     Weekend  hook & line    Charter boat
#
#                   Mode of fishing collapsed Collapsed area of fishing  \
# 0  Charter Boat (sub_reg=6 or 7 & mode_f=7)                    Inland
# 1  Charter Boat (sub_reg=6 or 7 & mode_f=7)                    Inland
# 2  Charter Boat (sub_reg=6 or 7 & mode_f=7)                    Inland
# 3  Charter Boat (sub_reg=6 or 7 & mode_f=7)                    Inland
# 4  Charter Boat (sub_reg=6 or 7 & mode_f=7)                    Inland
#
#   Distance from shore  Hours on boat  Hours fished Catch fish  \
# 0      not applicable            7.0           6.0        Yes
# 1      not applicable            5.0           4.5         No
# 2      not applicable            5.0           4.5         No
# 3      not applicable            6.0           4.0         No
# 4      not applicable            6.0           4.0         No
#
#    Number of fish avail for inspection
# 0                                    3
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0

# %%
#drop unsuasble data
#catch_df = catch_df.drop(['Date file created','Fish target species'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-72e014171f34> in <module>
#       1 #drop unsuasble data
# ----> 2 catch_df = catch_df.drop(['Date file created','Fish target species'],axis=1)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['Date file created' 'Fish target species'] not found in axis"

# %% [markdown]
# # Split the Data into Training and Testing

# %%
# Create our features
X = catch_df.drop('Catch fish', axis=1)

X = pd.get_dummies(X)

# Create our target
y = catch_df['Catch fish']

# %%
X.describe()
# Out:
#        Month of intercept  Time of intercept  Hours on boat  Hours fished  \
# count        20238.000000       20238.000000   20238.000000  20238.000000
# mean             7.485720        1322.732681       6.668421      4.394901
# std              2.098378         307.940640       2.553845      1.839168
# min              1.000000           2.000000       0.500000      0.500000
# 25%              6.000000        1202.000000       5.000000      3.000000
# 50%              7.000000        1359.000000       6.000000      4.000000
# 75%              9.000000        1532.000000       8.000000      5.500000
# max             12.000000        2359.000000      30.000000     24.000000
#
#        Number of fish avail for inspection  \
# count                         20238.000000
# mean                              5.044619
# std                              11.118904
# min                               0.000000
# 25%                               0.000000
# 50%                               1.000000
# 75%                               5.000000
# max                             300.000000
#
#        Data sampling period_January/February  \
# count                           20238.000000
# mean                                0.005584
# std                                 0.074516
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        Data sampling period_July/August  Data sampling period_March/April  \
# count                      20238.000000                      20238.000000
# mean                           0.331999                          0.048720
# std                            0.470942                          0.215288
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.000000                          0.000000
# 75%                            1.000000                          0.000000
# max                            1.000000                          1.000000
#
#        Data sampling period_May/June  Data sampling period_November/December  \
# count                   20238.000000                             20238.00000
# mean                        0.297806                                 0.09660
# std                         0.457305                                 0.29542
# min                         0.000000                                 0.00000
# 25%                         0.000000                                 0.00000
# 50%                         0.000000                                 0.00000
# 75%                         1.000000                                 0.00000
# max                         1.000000                                 1.00000
#
#        ...  Mode of fishing_Private/Rental boat  \
# count  ...                         20238.000000
# mean   ...                             0.477369
# std    ...                             0.499500
# min    ...                             0.000000
# 25%    ...                             0.000000
# 50%    ...                             0.000000
# 75%    ...                             1.000000
# max    ...                             1.000000
#
#        Mode of fishing collapsed_Charter Boat (sub_reg=6 or 7 & mode_f=7)  \
# count                                       20238.000000
# mean                                            0.226505
# std                                             0.418580
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Mode of fishing collapsed_Headboat  \
# count                        20238.000000
# mean                             0.296126
# std                              0.456559
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              1.000000
# max                              1.000000
#
#        Mode of fishing collapsed_Private/Rental Boat  \
# count                                   20238.000000
# mean                                        0.477369
# std                                         0.499500
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         1.000000
# max                                         1.000000
#
#        Collapsed area of fishing_Inland  \
# count                      20238.000000
# mean                           0.447574
# std                            0.497256
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            1.000000
# max                            1.000000
#
#        Collapsed area of fishing_Ocean <= 3 mi (all but WFL)  \
# count                                       20238.000000
# mean                                            0.255213
# std                                             0.435992
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        Collapsed area of fishing_Ocean > 3 mi (all but WFL)  \
# count                                       20238.000000
# mean                                            0.297213
# std                                             0.457042
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        Distance from shore_<= 3 miles (all but WFL)  \
# count                                  20238.000000
# mean                                       0.255213
# std                                        0.435992
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                        1.000000
#
#        Distance from shore_> 3 miles (all but in WFL)  \
# count                                    20238.000000
# mean                                         0.297213
# std                                          0.457042
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          1.000000
# max                                          1.000000
#
#        Distance from shore_not applicable
# count                        20238.000000
# mean                             0.447574
# std                              0.497256
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              1.000000
# max                              1.000000
#
# [8 rows x 36 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# Yes    11709
# No      8529
# Name: Catch fish, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_train
# Out:
#        Month of intercept  Time of intercept  Hours on boat  Hours fished  \
# 8253                    7               1312            7.5           3.0
# 7008                    5               1417            7.0           3.0
# 18653                  11               1531            8.0           5.0
# 12022                   8               1622            4.5           3.0
# 5265                    6               1220            5.0           4.0
# ...                   ...                ...            ...           ...
# 10955                   7               1609            5.0           4.0
# 17289                   9                815            7.0           2.5
# 5192                    6               1524            5.0           3.5
# 12172                   7               1330            6.0           4.5
# 235                     4                634           12.0           7.0
#
#        Number of fish avail for inspection  \
# 8253                                    19
# 7008                                     1
# 18653                                    1
# 12022                                    0
# 5265                                     0
# ...                                    ...
# 10955                                    1
# 17289                                    8
# 5192                                     0
# 12172                                    0
# 235                                     12
#
#        Data sampling period_January/February  \
# 8253                                       0
# 7008                                       0
# 18653                                      0
# 12022                                      0
# 5265                                       0
# ...                                      ...
# 10955                                      0
# 17289                                      0
# 5192                                       0
# 12172                                      0
# 235                                        0
#
#        Data sampling period_July/August  Data sampling period_March/April  \
# 8253                                  1                                 0
# 7008                                  0                                 0
# 18653                                 0                                 0
# 12022                                 1                                 0
# 5265                                  0                                 0
# ...                                 ...                               ...
# 10955                                 1                                 0
# 17289                                 0                                 0
# 5192                                  0                                 0
# 12172                                 1                                 0
# 235                                   0                                 1
#
#        Data sampling period_May/June  Data sampling period_November/December  \
# 8253                               0                                       0
# 7008                               1                                       0
# 18653                              0                                       1
# 12022                              0                                       0
# 5265                               1                                       0
# ...                              ...                                     ...
# 10955                              0                                       0
# 17289                              0                                       0
# 5192                               1                                       0
# 12172                              0                                       0
# 235                                0                                       0
#
#        ...  Mode of fishing_Private/Rental boat  \
# 8253   ...                                    0
# 7008   ...                                    1
# 18653  ...                                    1
# 12022  ...                                    0
# 5265   ...                                    1
# ...    ...                                  ...
# 10955  ...                                    1
# 17289  ...                                    0
# 5192   ...                                    0
# 12172  ...                                    0
# 235    ...                                    0
#
#        Mode of fishing collapsed_Charter Boat (sub_reg=6 or 7 & mode_f=7)  \
# 8253                                                   0
# 7008                                                   0
# 18653                                                  0
# 12022                                                  1
# 5265                                                   0
# ...                                                  ...
# 10955                                                  0
# 17289                                                  0
# 5192                                                   1
# 12172                                                  1
# 235                                                    0
#
#        Mode of fishing collapsed_Headboat  \
# 8253                                    1
# 7008                                    0
# 18653                                   0
# 12022                                   0
# 5265                                    0
# ...                                   ...
# 10955                                   0
# 17289                                   1
# 5192                                    0
# 12172                                   0
# 235                                     1
#
#        Mode of fishing collapsed_Private/Rental Boat  \
# 8253                                               0
# 7008                                               1
# 18653                                              1
# 12022                                              0
# 5265                                               1
# ...                                              ...
# 10955                                              1
# 17289                                              0
# 5192                                               0
# 12172                                              0
# 235                                                0
#
#        Collapsed area of fishing_Inland  \
# 8253                                  1
# 7008                                  0
# 18653                                 1
# 12022                                 0
# 5265                                  0
# ...                                 ...
# 10955                                 1
# 17289                                 0
# 5192                                  0
# 12172                                 1
# 235                                   0
#
#        Collapsed area of fishing_Ocean <= 3 mi (all but WFL)  \
# 8253                                                   0
# 7008                                                   0
# 18653                                                  0
# 12022                                                  1
# 5265                                                   1
# ...                                                  ...
# 10955                                                  0
# 17289                                                  0
# 5192                                                   1
# 12172                                                  0
# 235                                                    0
#
#        Collapsed area of fishing_Ocean > 3 mi (all but WFL)  \
# 8253                                                   0
# 7008                                                   1
# 18653                                                  0
# 12022                                                  0
# 5265                                                   0
# ...                                                  ...
# 10955                                                  0
# 17289                                                  1
# 5192                                                   0
# 12172                                                  0
# 235                                                    1
#
#        Distance from shore_<= 3 miles (all but WFL)  \
# 8253                                              0
# 7008                                              0
# 18653                                             0
# 12022                                             1
# 5265                                              1
# ...                                             ...
# 10955                                             0
# 17289                                             0
# 5192                                              1
# 12172                                             0
# 235                                               0
#
#        Distance from shore_> 3 miles (all but in WFL)  \
# 8253                                                0
# 7008                                                1
# 18653                                               0
# 12022                                               0
# 5265                                                0
# ...                                               ...
# 10955                                               0
# 17289                                               1
# 5192                                                0
# 12172                                               0
# 235                                                 1
#
#        Distance from shore_not applicable
# 8253                                    1
# 7008                                    0
# 18653                                   1
# 12022                                   0
# 5265                                    0
# ...                                   ...
# 10955                                   1
# 17289                                   0
# 5192                                    0
# 12172                                   1
# 235                                     0
#
# [15178 rows x 36 columns]

# %% [markdown]
# # Oversampling
#
# In this section, you will compare two oversampling algorithms to determine which algorithm results in the best performance. You will oversample the data using the naive random oversampling algorithm and the SMOTE algorithm. For each algorithm, be sure to complete the folliowing steps:
#
# 1. View the count of the target classes using `Counter` from the collections library.
# 3. Use the resampled data to train a logistic regression model.
# 3. Calculate the balanced accuracy score from sklearn.metrics.
# 4. Print the confusion matrix from sklearn.metrics.
# 5. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
#
# Note: Use a random state of 1 for each sampling algorithm to ensure consistency between tests

# %% [markdown]
# ### Naive Random Oversampling

# %%
# Resample the training data with the RandomOversampler
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)
Counter(y_resampled)
# Out:
# Counter({'Yes': 8753, 'No': 8753})

# %%
# Train the Logistic Regression model using the resampled data
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
y_pred = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[2104,    0],
#        [   0, 2956]])

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#          No       1.00      1.00      1.00      1.00      1.00      1.00      2104
#         Yes       1.00      1.00      1.00      1.00      1.00      1.00      2956
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00      5060

# %% [markdown]
# # Undersampling
#
# In this section, you will test an undersampling algorithms to determine which algorithm results in the best performance compared to the oversampling algorithms above. You will undersample the data using the Cluster Centroids algorithm and complete the folliowing steps:
#
# 1. View the count of the target classes using `Counter` from the collections library.
# 3. Use the resampled data to train a logistic regression model.
# 3. Calculate the balanced accuracy score from sklearn.metrics.
# 4. Print the confusion matrix from sklearn.metrics.
# 5. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
#
# Note: Use a random state of 1 for each sampling algorithm to ensure consistency between tests

# %%
# Resample the data using the ClusterCentroids resampler
# Warning: This is a large dataset, and this step may take some time to complete
from collections import Counter
from imblearn.under_sampling import ClusterCentroids
cc = ClusterCentroids(random_state=1)
X_resampled, y_resampled = cc.fit_resample(X_train, y_train)
Counter(y_resampled)
# Out:
# Counter({'No': 6425, 'Yes': 6425})

# %%
# Train the Logistic Regression model using the resampled data
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
# Display the confusion matrix
y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[2104,    0],
#        [   0, 2956]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#          No       1.00      1.00      1.00      1.00      1.00      1.00      2104
#         Yes       1.00      1.00      1.00      1.00      1.00      1.00      2956
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00      5060

# %% [markdown]
# # Combination (Over and Under) Sampling
#
# In this section, you will test a combination over- and under-sampling algorithm to determine if the algorithm results in the best performance compared to the other sampling algorithms above. You will resample the data using the SMOTEENN algorithm and complete the folliowing steps:
#
# 1. View the count of the target classes using `Counter` from the collections library.
# 3. Use the resampled data to train a logistic regression model.
# 3. Calculate the balanced accuracy score from sklearn.metrics.
# 4. Print the confusion matrix from sklearn.metrics.
# 5. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
#
# Note: Use a random state of 1 for each sampling algorithm to ensure consistency between tests

# %%
# Resample the training data with SMOTEENN
# Warning: This is a large dataset, and this step may take some time to complete
from imblearn.combine import SMOTEENN
smote_enn = SMOTEENN(random_state=0)
X_resampled, y_resampled = smote_enn.fit_resample(X, y)
Counter(y_resampled)
# Out:
# Counter({'No': 9907, 'Yes': 8854})

# %%
# Train the Logistic Regression model using the resampled data
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
# Display the confusion matrix
y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[2104,    0],
#        [   0, 2956]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#          No       1.00      1.00      1.00      1.00      1.00      1.00      2104
#         Yes       1.00      1.00      1.00      1.00      1.00      1.00      2956
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00      5060
